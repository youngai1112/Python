# %%
a = 1 # 변수 a를 1로 초기화

# %%
print(a)
# Out:
# 1

# %%
a = 2 # 변수 a에 2를 대입(할당)

print(a)
# Out:
# 2

# %% [markdown]
# # command (주석)
# 코드가 진행되는 방향은 위->아래, 주석이 없이 코멘트 작성시 오류
#   * 코드에서 #으로 시작하는 부분으로써, 실행되지 않는다.
#   * 개발자가 어떠한 코드인지 설명할 때 사용

# %%
# 변수의 선언과 할당
a = 1 # 변수 a를 선언하고 1을 할당
a
# Out:
# 1

# %% [markdown]
# # 자료형 (Data Type)
# 프로그래밍에서 사용되어지는 기본적인 형식(타입)
#
# * int(정수) : -3, -2, 1, 3, 5
# * float(실수) : 3.14, -1.3, 20.1
#   * 3.0 은 **실수**
# * str(문자열)
# * bool(논리)

# %%
 a = 1 # a 변수에 정수 1을 대입
 type(a)
# Out:
# int

# %%
a = 3.14
type(a)
# Out:
# float

# %%
a = 'Good morning~!'
type(a)
# Out:
# str

# %%
a = True
type(a)
# Out:
# bool

# %%
True + True
# Out:
# 2

# %%
False + True
# Out:
# 1

# %% [markdown]
# # variable naming(변수 이름 규칙)
# 가장 많이 실수하는 부분!

# %%
studentName = "minho" # camel case. python에서는 잘 사용하지 않는다. 일반 변수 이름 지을 때에 잘 사용하지 않는다.
student_name = "minho" # snake case. python에서 변수, 함수를 만들 때 이름을 붇여주는 방법

# %%
학생이름 = "민호"
학생이름
# Out:
# '민호'

# %% [markdown]
# 한글로도 변수의 이름을 지을 수 있으나 비추
# 변수와 상수는 일반적으로 소문자로 시작한다

# %%
_student = "minho" # 언더바로 시작한다면, 변수이지만 개발의 입장으로 봤을때 상수 취급을 한다.

# _student = "jinho" # 상수는 수정하지 않음. 사용만하고 건들지 말자 **절대**

STUDENT_NAME = "minho" # 대문자와 언더바만을 이용해서 만들면 상수

# %%
a = 10
b = "민호"

age = 10
name = "민호"

# %% [markdown]
# # 아무런 값을 갖지 않는 변수

# %%
c = None

# %% [markdown]
# 휴지가 없다면 0, 휴지심마저 없다면 None
